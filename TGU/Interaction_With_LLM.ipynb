# %% [markdown]
# ## Intro
# * Input: the prompt we send to the LLM.
# * Output: the response from the LLM.
# * We can switch LLMs and use several different LLMs.

# %% [markdown]
# ## LangChain divides LLMs in two types
# 1. LLM Model: text-completion model.
# 2. Chat Model: converses with a sequence of messages and can have a particular role defined (system prompt). This type has become the most used in LangChain.

# %% [markdown]
# ## Difference Between Chat Models and Completion Models
#
# 1. **Chat Models**:
#    - Designed for structured conversational input.
#    - Use a message-based format where each message has a role (e.g., `user`, `assistant`, `system`) and content.
#    - Ideal for multi-turn interactions, chatbots, or scenarios requiring explicit context handling.
#    - Examples: Models like `ChatOpenAI` support chat-based APIs (e.g., `gpt-3.5-turbo`, `gpt-4`).
#    - ChatOpenAI(model,temperature,max_tokens,api_key)
#       - e.g model="gpt-3.5-turbo",temperature=0.7,max_tokens=100,openai_api_key
#    - ChatGoogleGenerativeAI
#       - e.g model="gemini-1.5-flash",temperature=0.7,max_tokens=100,google_api_key
#
# 2. **Completion Models**:
#    - Designed for free-form text input.
#    - Input is a single string prompt, without predefined roles or structure.
#    - It is suitable for one-off tasks such as text completion, summarization, or code generation.
#    - Examples: Models like `OpenAI` support text-completion APIs (e.g., `gpt-3.5-turbo`).
#    - OpenAI(model,temperature,max_tokens,api_key)
#       - e.g model="gpt-3.5-turbo",temperature=0.7,max_tokens=100,api_key
#
#    - GoogleGenerativeAI(model,temperature,max_tokens,api_key)
#       - e.g model="gemini-1.5-flash",temperature=0.7,max_tokens=100,google_api_key
#
# | **Aspect**               | **Chat Models**                             | **Completion Models**                     |
# |--------------------------|---------------------------------------------|------------------------------------------|
# | **Input Format**         | List of messages with roles.               | Single string prompt.                    |
# | **Use Case**             | Conversational AI, multi-turn tasks.        | Text completion, summarization, single-turn tasks. |
# | **Context Handling**     | Maintains multi-turn context effectively.   | Requires explicit context in the prompt. |

# %% [markdown]
# ## List of LLMs that can work with LangChain
# * See the list [here](https://python.langchain.com/v0.1/docs/integrations/llms/).

# %% [markdown]
# ### `find_dotenv()`
# - **What it Does**:
#   Searches for a `.env` file in the current directory or parent directories.
# - **Return Value**:
#   - If a `.env` file is found: Returns the full path to the `.env` file.
#     Example: `/home/user/project/.env`
#   - If no `.env` file is found: Returns an empty string (`""`).
#
# ---
#
# ### `load_dotenv()`
# - **What it Does**:
#   Loads the key-value pairs from the `.env` file found by `find_dotenv()` into the environment variables of the program.
# - **Behavior**:
#   - If a `.env` file is found: Updates the environment variables with the key-value pairs.
#   - If no `.env` file is found: Does nothing.

# %%
## Following code will fetch the key-value pairs from the environment variables of the program
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())  # Althouh it will return True if the key-value pairs are fetched successfully, but we don't need to store it in any variable.
openai_api_key = os.getenv("OPENAI_API_KEY")
google_api_key=os.getenv("GOOGLE_API_KEY")
cerebras_api_key=os.getenv("CEREBRAS_API_KEY")   
groq_api_key=os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### 1. Completion Model
# * These were very popular in the earlier era of LLMs but are not as widely used in recent times.
# * You can find the LangChain documentation about LLM models [here](https://python.langchain.com/v0.1/docs/modules/model_io/llms/).
# * Getting the response you can use the method like :
#     - invoke()
#     - stream()
#     - batch()

# %%
# ## OpenAI based Completion model
# from langchain_openai import OpenAI
# # Initialize the OpenAI model
# llm_openai = OpenAI(model="gpt-5.4-nano",openai_api_key=openai_api_key)  # Creating an instance of the ChatOpenAI class with a specific API key
# # Invoke the model with a prompt
# response = llm_openai.invoke("Name of all the captains who won the World Cup cricket for India")
# # Print the response
# print(response)

#####################################################
# ## Google based Completion model
# from langchain_google_genai import GoogleGenerativeAI
# llm_google=GoogleGenerativeAI(model="gemini-2.5-flash",google_api_key=google_api_key) # Creating an instance of the ChatOpenAI class with a specific API key
# response=llm_google.invoke("Name of all the captains who won the T20 World Cup cricket for India?")  # Invoking the instance with a specific message
# print(type(response))  # Printing the type of the response received from the instance
# print(response)  # Printing the response received from the instance 

# ######################################################
# Import the necessary class from langchain_ollama
from langchain_ollama import OllamaLLM   # Initialize the Ollama model
ollama_model = OllamaLLM(model="llama3.2:3b")  # You can specify the model you want to use, like "llama3.2:1b"
prompt = "Who is the chief Minister of Delhi?"
response = ollama_model.invoke(prompt) # Get the response from the Ollama model
print(response)  # Printing the response received from the instance

####################################################### NOT WORKING CURRENTLY
# from langchain_cohere.llms import Cohere
# Coher_model = Cohere()
# prompt = "What is the capital of France?"
# response = Coher_model.invoke(prompt) # Get the response from the Cohere model 
# print(response)  # Printing the response received from the instance
# Out:
# The Chief Minister of Delhi is Arvind Kejriwal. He has been serving as the Chief Minister of Delhi since February 2015 and has won three consecutive terms in office.

# %%
from langchain_google_genai import GoogleGenerativeAI
llm_google=GoogleGenerativeAI(model="gemini-2.5-flash")
response=llm_google.stream("Write the 500 words of poem on Cricket")
print(response) ## Stream Object
for chunk in response:
    print(chunk,end='',flush=True)
# Out:
# <generator object BaseLLM.stream at 0x110a234c0>
# The emerald stage, beneath a sky so vast,
# Where sun-drenched dreams and legends are cast.
# A hallowed ground, meticulously mown,
# Where every blade of grass has its story known.
# Three wooden sentinels, stark and white,
# With bails perched lightly, in morning's light.
# The 22 yards, a sacred strip,
# Where fate can turn with a single slip.
# The red cherry gleams, a polished sphere,
# Whispering promises, dispelling fear,
# Or planting doubt, with a wicked spin,
# As the epic battle is set to begin.
#
# From the pavilion, the figures stride,
# With purpose etched, and a silent pride.
# The batsman, armed with a willow blade,
# A fortress built, a challenge made.
# Pads gleaming white, a helmet worn,
# For the fiery onslaught, from dusk till morn.
# He eyes the field, a strategic mind,
# For gaps to exploit, runs to find.
# Then from the boundary, with rhythmic grace,
# The bowler charges, a focused face.
# A run-up measured, a powerful bound,
# As the leather missile leaves the ground.
#
# It swings, it seams, it dips, it turns,
# A fiery question, the batsman learns.
# To defend with honour, or to attack with might,
# To choose his moment, in the fading light.
# A cover drive, majestic, clean and true,
# Sends the ball racing, across the dew.
# A flick through leg, a delicate touch,
# Each run a treasure, meaning so much.
# The roar of the crowd, a rising tide,
# As boundaries are struck, with glorious stride.
# A cheer erupts, for a six so grand,
# Landing far out, in the distant stand.
#
# But then the silence, tense and deep,
# As a wicket falls, secrets to keep.
# A sharp bouncer, a deceptive slower ball,
# The stumps are shattered, the bails will fall.
# The umpire's finger, raised to the sky,
# A moment of despair, a whispered sigh.
# The fielders scatter, with agile grace,
# Diving, leaping, in this frantic race.
# A stunning catch, plucked from thin air,
# A moment of brilliance, beyond compare.
# The wicketkeeper crouched, a watchful eye,
# For stumping chances, as the overs fly.
#
# The ebb and flow, a captivating dance,
# Where fortunes alter, at a single glance.
# From Test match patience, a five-day quest,
# To ODI thrillers, putting skill to the test.
# The T20 frenzy, a rapid-fire spree,
# Each format a jewel, for all to see.
# The strategy unfolds, complex and vast,
# As captains ponder, how long it can last.
# Partnerships blossom, like flowers in spring,
# As two united, the scoreboard they bring.
# To heights unmeasured, with courage and art,
# Playing with passion, from the very start.
#
# The sun descends, casting shadows long,
# As the final overs echo cricket's song.
# A nail-biting finish, hearts in the throat,
# Every single run, a crucial note.
# The tension palpable, a heavy cloak,
# Until the winning shot, or the final stroke.
# Then triumph explodes, a joyous cheer,
# Or quiet heartbreak, a silent tear.
# For in this game, of skill and of chance,
# There's sportsmanship woven, in every glance.
# A handshake offered, respect profound,
# On this most glorious, cricketing ground.
#
# More than a sport, it's a way of life,
# Cutting through borders, calming all strife.
# From dusty pitches, in villages far,
# To floodlit stadiums, beneath a star.
# A universal language, understood by all,
# Answering cricket's captivating call.
# The crack of the bat, the thud of the leather,
# These are the sounds that bind us together.
# Through generations, its spirit endures,
# A game of heroes, and timeless allure.
# Oh, Cricket, dear Cricket, forever you'll reign,
# In our hearts and our memories, again and again.

# %%
## OpenAI based Completion model with Stream function
from langchain_openai import OpenAI
# Initialize the OpenAI model
llm_openai = OpenAI(model="gpt-5.4-nano")
# Invoke the model with a stream
response = llm_openai.stream("Name of all the captains who won the World Cup cricket for India?")
# Print the response as streaming
for chunk in response:
  print(chunk, end="", flush=True)

# %%
## OpenAI based Completion model with batch function
from langchain_google_genai import GoogleGenerativeAI
# Initialize the OpenAI model
llm_google = GoogleGenerativeAI(model="gemini-2.5-flash")
# Invoke the model with a batch of prompts
response = llm_google.batch(["Name of the PM of India", "What is the name of the capital of India"])
# Print the response as streaming
print(type(response)) 
print(len(response)) 
print(response[0])
print(response[1])

# %%
# ## OpenAI based Completion model with batch function
from langchain_openai import OpenAI
# Initialize the OpenAI model
llm_openai = OpenAI(model="gpt-3.5-turbo-instruct")
# Invoke the model with a batch of prompts
response = llm_openai.batch(["Name of the PM of India", "What is the name of the capital of India"])
# Print the response as streaming
print(response)

# %% [markdown]
# ### 2. Chat Model
# * The general trend after the launch of ChatGPT-4.
#     * Frequently referred to as a "Chatbot."
#     * Enables conversations between humans and AI.
#     * Can include a system prompt to define the tone or role of the AI.
# * See LangChain documentation about Chat Models [here](https://python.langchain.com/v0.1/docs/modules/model_io/chat/).
# * By default we will work with ChatOpenAI. See the LangChain documentation page about it  [here](https://python.langchain.com/v0.1/docs/integrations/chat/openai/).

# %%
# ## OpenAI based Chat model
# from langchain_openai import ChatOpenAI
# # Initialize the OpenAI model
# llm_openai = ChatOpenAI(model="gpt-5-nano")
# # Invoke the model with a prompt
# response = llm_openai.invoke("Who are you?, who have trained you and what is your purpose?")
# # Print the response
# print(response)
# print("/\/------------------//")
# print(type(response))
# print("/\/------------------//")
# print(response.content) 

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>#
# # Google Generative AI based Chat model
# from langchain_google_genai import ChatGoogleGenerativeAI
# # Initialize the Google Generative AI model
# llm_google = ChatGoogleGenerativeAI(  # Creating an instance of the ChatOpenAI class with a specific API key
#     model="gemini-2.5-flash"
# )
# response=llm_google.invoke("Hello, how are you?")  # Invoking the instance with a specific message
# print(type(response))  # Printing the type of the response received from the instance
# print(response.content)  # Printing the response received from the instance 

##<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>#
# Ollama based Chat model
from langchain_ollama import ChatOllama   # Initialize the Ollama model
ollama_model = ChatOllama(model="llama3.2:3b")  # You can specify the model you want to use, like "llama3.2:1b"
prompt = "explain activity components in react" 
response = ollama_model.invoke(prompt) # Get the response from the Ollama model
print(response)  # Printing the response received from the instance
print(response.content)  # Printing the response received from the instance

##<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>#
# # Cohere based Chat model
# from langchain_cohere import ChatCohere
# Coher_model = ChatCohere()
# prompt = "What is the capital of Australia?"
# response = Coher_model.invoke(prompt) # Get the response from the Cohere model
# print(response.text)  # Printing the response received from the instance

##<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>#
# # Groq based Chat model
from langchain_groq import ChatGroq
Groq_model = ChatGroq(temperature=1, model_name="llama-3.1-8b-instant")
prompt = "poem on cricket in 100 words"
response = Groq_model.invoke(prompt) # Get the response from the Cohere model
# print(response)  # Printing the response received from the instance
print(response.content)  # Printing the response received from the instance

##<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>#
# from langchain_cerebras import ChatCerebras
# Cerebras_model = ChatCerebras(temperature=0, model="llama-3.3-70b")
# prompt = "What is the capital of France?"
# response = Cerebras_model.invoke(prompt) # Get the response from the Cohere model
# print(response)  # Printing the response received from the instance
# print(response.content)  # Printing the response received from the instance 

##<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<USE OF stream() and batch() as well >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>#
## Use of Batch
# from langchain_cerebras import ChatCerebras
# Cerebras_model = ChatCerebras(temperature=0, model="llama-3.3-70b")
# prompt = ["What is the capital of France?","What is the capital of India?"]
# response = Cerebras_model.batch(prompt) # Get the response from the Cohere model
# # print(response)  # Printing the response received from the instance
# print(response[0].content)  # Printing the response received from the instance
# print(response[1].content)  # Printing the response received from the instance

## Use of Stream
# from langchain_cerebras import ChatCerebras
# Cerebras_model = ChatCerebras(temperature=0, model="llama-3.3-70b")
# prompt = "Write a poem of apprx 100 words on holy cow"
# response = Cerebras_model.stream(prompt) # Get the response from the Cohere model

# for chunk in response:
#   print(chunk.content, end="", flush=True)

# %%
print(response.content_blocks)

# %%
print(response.content_blocks[0].keys())

# %%
# Getting the metadata of the response
response.response_metadata

# %%
## Getting the usage of the response
response.usage_metadata

# %%
from pprint import pp
pp(response.__dict__)
